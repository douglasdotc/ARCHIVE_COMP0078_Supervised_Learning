# %%
# ======================================
# COMP0078 Coursework 2 Q1.7 RE1.2 (SVM)
# Douglas Chiang
# 15055142
# ======================================
cd /content/drive/MyDrive/Colab Notebooks/COMP0078/CW2/Q1
# Out:
# /content/drive/MyDrive/Colab Notebooks/COMP0078/CW2/Q1

# %%
ls
# Out:
#  Assignment_2_Question_1a_v3.ipynb     dtrain123.dat
#  Assignment_2_Question_1e_2_v1.ipynb   Plots/
#  assignment_2_question_1f_1_v1.py     'Q1 Trial.ipynb'
#  assignment_2_question_1f_v1.py        zipcombo.dat
#  dtest123.dat

# %%
import time
import pandas            as pd
import numpy             as np
import matplotlib.pyplot as plt
from   sklearn           import svm

# %%
def load_dat(fname, Full_Data = False):
    dat = pd.read_csv(fname, sep='\s+', header=None).to_numpy()
    if Full_Data == False:
        y = dat[:, 0].astype(np.int) - 1  # we are zero-based indexing
    else:
        y = dat[:, 0].astype(np.int)
    
    X = dat[:, 1:].astype(np.float64)
    return X, y

def kFold(data_idx, fold, folds):
    # Return split data indices sets for k-fold validation
    
    if fold > folds - 1:
        raise Exception('fold number exceeds total folds available')
    
    m        = len(data_idx)
    size     = m // folds
    data_validate_idx = data_idx[fold*size:(fold + 1)*size]

    if fold == 0:
        # first fold
        data_train_idx = data_idx[(fold+1)*size:]

    elif fold == folds - 1:
        # last fold
        data_train_idx = data_idx[:fold*size]

    else:
        # middle fold
        data_train1_idx = data_idx[:fold*size]
        data_train2_idx = data_idx[(fold+1)*size:]
        data_train_idx  = np.concatenate((data_train1_idx, data_train2_idx), axis=0)
    
    return data_train_idx, data_validate_idx

# %%
X_dataset, Y_dataset = load_dat("zipcombo.dat", Full_Data = True)
# split_pt = round(X_dataset.shape[0]*0.1)
# X_dataset = X_dataset[:split_pt]
# Y_dataset = Y_dataset[:split_pt]

# %%
n_epochs  = 1
#C_All = [5,6,7,8,9,10,11]
C_All = [0.5, 1, 10, 50, 100, 500, 1000]
# Question 1b):
Testing_Error_per_run  = []
d_star_per_run         = []

# Question 1c):
confusion_matrix = []

# Question 1d):
prediction_mistake_count = np.zeros((Y_dataset.shape[0],1))

# Question 1b):
# Loop for 20 runs
for run in range(1,21):
    print("Run: {}".format(run))

    # 8:2 Split training + validation and testing set:
    # Index Shuffle for fitting:
    ran_sample_idx               = np.random.permutation(len(Y_dataset))
    split_pt                     = round(len(ran_sample_idx)*0.8)
    ran_trainvalidate_sample_idx = ran_sample_idx[:split_pt]
    ran_test_sample_idx          = ran_sample_idx[split_pt:len(ran_sample_idx)]
    n_train_validate_samples     = len(ran_trainvalidate_sample_idx)
    n_test_samples               = len(ran_test_sample_idx)
    
    # Loop for d from 1 to 7
    avg_validation_correct = []
    for C_test in C_All:
        print("d = {}".format(C_test))

        # 1b) 5 folds cross validation:
        validation_correct_all = []
        folds = 5
        for fold in range(0, folds):
            print(f"fold: {fold + 1}")

            # Get indicies for training set and validation set:
            data_train_idx, data_validate_idx = kFold(ran_trainvalidate_sample_idx, fold, folds)

            # Data sets:
            X_train              = X_dataset[data_train_idx]
            Y_train              = Y_dataset[data_train_idx]
            X_validate           = X_dataset[data_validate_idx]
            Y_validate           = Y_dataset[data_validate_idx]

            nsamples             = len(data_train_idx)

            # Initialize:
            svm_clf              = svm.SVC(C = C_test, gamma='auto')

            for epoch in range(1, n_epochs + 1):
                tic    = time.time()
                train  = svm_clf.fit(X_train, Y_train)
                toc    = time.time()
                
                print(f"**Training: Epoch {epoch} finished in {toc - tic:0.4f} seconds")
                epoch += 1
            
            # 1b) Validate:
            # ---------------Validation Accuracy-----------------
            validate_correct = 0
            pred             = svm_clf.predict(X_validate)
            validate_correct = sum(Y_validate == pred)
            
            # 1b )Record results:
            validation_correct_all.append(validate_correct)

        # 1b) Save all average validation correct for selection:
        avg_validation_correct.append(np.sum(validation_correct_all)/folds)
    
    # 1b) Select the best d (d*)
    d_star = C_All[np.argmax(avg_validation_correct)]

    # 1b) Retrain using d* on full 80% training set
    print(f"Retrain using C* = {d_star}...")
    X_trainval   = X_dataset[ran_trainvalidate_sample_idx]
    Y_trainval   = Y_dataset[ran_trainvalidate_sample_idx]
    # Initialize:
    svm_clf = svm.SVC(C = d_star, gamma='auto')
    
    for epoch in range(1, n_epochs + 1):
        tic    = time.time()
        train  = svm_clf.fit(X_trainval, Y_trainval) # Full 80%
        toc    = time.time()
        
        print(f"**Training: Epoch {epoch} finished in {toc - tic:0.4f} seconds")
        epoch += 1
    
    # 1b) Test on testing set:
    # ---------------Testing Accuracy-------------------
    print("Testing...")
    X_test       = X_dataset[ran_test_sample_idx]
    Y_test       = Y_dataset[ran_test_sample_idx]
    Test_correct = 0
    pred         = svm_clf.predict(X_test)
    Test_correct = sum(Y_test == pred)

    # 1c) Fill confusion matrix:
    confusion_matrix_per_run = np.zeros((10,10)) # 0 - 9
    label_count = np.zeros((10,1))
    for i, j in zip(Y_test, pred):
        label_count[i] += 1
        if i != j:
            confusion_matrix_per_run[i,j] += 1
    confusion_matrix_per_run = confusion_matrix_per_run/label_count
    
    # 1b) Record test error and mean d*
    Test_error = (n_test_samples - Test_correct)/n_test_samples
    Testing_Error_per_run.append(Test_error)
    d_star_per_run.append(d_star)

    # 1c) Record confusion matrix:
    confusion_matrix.append(confusion_matrix_per_run)

    # 1d) 5 worst data:
    print("Prediction mistake count...")
    pred         = svm_clf.predict(X_dataset)
    for i in range(Y_dataset.shape[0]):
        if Y_dataset[i] != pred[i]:
            prediction_mistake_count[i] += 1

worst_5_idx = np.argsort(-prediction_mistake_count.T)[0,:5]

print("Results 1b):")
print(f"Testing error per run: {Testing_Error_per_run}")
print(f"d* per run: {d_star_per_run}")
print(f"Mean and STD of testing error: {np.mean(Testing_Error_per_run)} +- {np.std(Testing_Error_per_run)}")
print(f"Mean and STD of d*: {np.mean(d_star_per_run)} +- {np.std(d_star_per_run)}")

print("\nResults 1c):")
print(f"Mean confusion matrix:")
print(np.mean(confusion_matrix, axis = 0))
print(f"STD confusion matrix:")
print(np.std(confusion_matrix, axis = 0))

print("\nResults 1d):")
plot_idx = 1
for idx in worst_5_idx:
    plt.subplot(1, 5, plot_idx)
    img = np.reshape(X_dataset[idx], (16,16))
    plt.imshow(img)
    plt.axis('off')
    plt.title('%d' % Y_dataset[idx])
    plot_idx += 1
# Out:
# Run: 1
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.3449 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.1872 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.3474 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.2606 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.3074 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.5022 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.5250 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.4719 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.5605 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.4797 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 2.9740 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9143 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9441 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9793 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9302 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 2.9757 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8758 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0361 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9531 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8822 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 3.0021 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.1341 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9732 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9823 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8826 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 3.0076 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9179 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9434 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9667 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8837 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 2.9746 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8906 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9430 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9318 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9072 seconds
# Retrain using C* = 10...
# **Training: Epoch 1 finished in 4.0964 seconds
# Testing...
# Prediction mistake count...
# Run: 2
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.3103 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.2957 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.2608 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.2260 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.3023 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.5634 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.4908 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.5079 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.3919 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.4440 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 2.9641 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9521 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9217 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0260 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8714 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 2.9767 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0328 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9865 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9136 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9551 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 3.0874 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9418 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9445 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0543 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.0490 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 3.3640 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0207 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0025 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9433 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8970 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 2.9754 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9458 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9120 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9167 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9067 seconds
# Retrain using C* = 10...
# **Training: Epoch 1 finished in 4.0429 seconds
# Testing...
# Prediction mistake count...
# Run: 3
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.1967 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.1729 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.2490 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.2837 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.2135 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.4422 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.4257 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.4986 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.7600 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.7248 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 3.0563 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9352 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9135 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9327 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8952 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 2.9346 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9612 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9179 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9843 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8739 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 2.9399 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9557 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9120 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9718 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9229 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 2.9442 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9768 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9029 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9715 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8807 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 2.9659 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9660 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9322 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9470 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9091 seconds
# Retrain using C* = 10...
# **Training: Epoch 1 finished in 4.0932 seconds
# Testing...
# Prediction mistake count...
# Run: 4
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.2230 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.3742 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.2803 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.2387 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.2672 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.6837 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.5345 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.6674 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.5568 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.5256 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 2.9284 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0214 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9368 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0049 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9470 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 3.0328 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0195 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.2971 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0046 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.2274 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 3.0788 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.1269 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0701 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.2053 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.1024 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 3.2575 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9536 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.1681 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0186 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.2251 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 3.0100 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.2124 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.1099 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.1429 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9994 seconds
# Retrain using C* = 10...
# **Training: Epoch 1 finished in 4.3624 seconds
# Testing...
# Prediction mistake count...
# Run: 5
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.2313 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.2434 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.4230 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.4899 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.3899 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.5120 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.7903 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.5387 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.7218 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.5678 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 3.1658 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0343 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9587 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0364 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.1660 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 3.0909 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0457 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9144 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0641 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9880 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 2.9388 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8909 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9288 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9939 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9583 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 2.9444 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9283 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9633 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0734 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.0493 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 3.0851 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9798 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0266 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.1275 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9890 seconds
# Retrain using C* = 10...
# **Training: Epoch 1 finished in 4.2749 seconds
# Testing...
# Prediction mistake count...
# Run: 6
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.1787 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.2985 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.2150 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.2225 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.2952 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.4799 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.6057 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.8152 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.6339 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.6088 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 2.9322 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9919 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.8830 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9846 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.0635 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 3.0464 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.1703 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0003 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0229 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.1408 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 3.0936 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9999 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9035 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9319 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9707 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 2.9998 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0293 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.8858 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9161 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9288 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 3.0345 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9556 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9280 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9144 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9553 seconds
# Retrain using C* = 10...
# **Training: Epoch 1 finished in 4.1108 seconds
# Testing...
# Prediction mistake count...
# Run: 7
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.2800 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.2717 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.2985 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.3652 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.3753 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.5916 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.6422 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.5449 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.3756 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.4995 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 3.0030 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0089 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.8291 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8522 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9970 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 3.1505 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.1362 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0459 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8622 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9126 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 3.2205 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9914 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.1027 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9514 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9748 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 2.9836 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9591 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9401 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8896 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9198 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 2.9925 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8948 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9946 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0523 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.0687 seconds
# Retrain using C* = 10...
# **Training: Epoch 1 finished in 4.0582 seconds
# Testing...
# Prediction mistake count...
# Run: 8
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.4630 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.3609 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.3467 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.2691 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.3832 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.6466 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.5862 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.6664 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.6460 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.5744 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 2.9455 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9656 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0956 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.1088 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8703 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 3.0653 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0758 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9071 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8783 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8808 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 3.1170 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0772 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9858 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0190 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8932 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 2.8546 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9607 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0062 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8812 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8779 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 2.8955 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9850 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.8988 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8583 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.0957 seconds
# Retrain using C* = 10...
# **Training: Epoch 1 finished in 4.3771 seconds
# Testing...
# Prediction mistake count...
# Run: 9
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.1567 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.1546 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.3752 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.2040 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.2910 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.5805 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.5389 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.4586 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.6443 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.6807 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 3.0393 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9762 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9630 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8913 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9237 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 3.2275 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9465 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.1659 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0210 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8964 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 2.8235 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8467 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0650 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8927 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9616 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 2.9326 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8439 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.8775 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9162 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8581 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 3.1975 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9221 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9623 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.1193 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8442 seconds
# Retrain using C* = 10...
# **Training: Epoch 1 finished in 3.9442 seconds
# Testing...
# Prediction mistake count...
# Run: 10
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.3280 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.1721 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.1901 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.3839 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.3649 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.3735 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.4177 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.4503 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.3919 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.4921 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 2.9591 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8018 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0873 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8476 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9209 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 2.8574 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8115 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.1071 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8305 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8456 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 2.7922 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.7995 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0111 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8742 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9574 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 2.9181 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9624 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9343 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9941 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8552 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 2.7885 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8218 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0205 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8297 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9094 seconds
# Retrain using C* = 50...
# **Training: Epoch 1 finished in 4.3148 seconds
# Testing...
# Prediction mistake count...
# Run: 11
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.2979 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.4953 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.3401 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.2329 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.2205 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.5687 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.6042 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.5021 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.4152 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.7901 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 2.9151 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9489 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.3301 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.1093 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.0708 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 2.9680 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.1278 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9297 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8958 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9479 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 2.9133 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0146 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0660 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.4401 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9391 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 2.9048 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0259 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.1802 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.1215 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9746 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 3.0590 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9761 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9712 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9721 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9619 seconds
# Retrain using C* = 10...
# **Training: Epoch 1 finished in 4.2770 seconds
# Testing...
# Prediction mistake count...
# Run: 12
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.3082 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.4838 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.2935 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.1939 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.3711 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.4846 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.3992 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.5648 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.4739 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.5094 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 3.0992 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8652 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0938 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0918 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8887 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 3.0539 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0682 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9808 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9093 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9447 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 2.9311 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9701 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.8942 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0885 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.1270 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 3.1608 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0493 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0853 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.1274 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9759 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 3.0073 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9060 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9394 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.1435 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.1057 seconds
# Retrain using C* = 10...
# **Training: Epoch 1 finished in 4.1275 seconds
# Testing...
# Prediction mistake count...
# Run: 13
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.4263 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.2288 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.4557 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.5214 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.3812 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.7265 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.6324 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.7876 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.7022 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.5154 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 2.9835 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0140 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0513 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.3768 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.1401 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 3.0726 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0632 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.1195 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0858 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.0714 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 3.1413 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0129 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9997 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9771 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.1380 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 3.0507 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0343 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0062 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.1758 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.0853 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 3.1289 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9663 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0776 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0625 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8787 seconds
# Retrain using C* = 10...
# **Training: Epoch 1 finished in 4.0642 seconds
# Testing...
# Prediction mistake count...
# Run: 14
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.2884 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.3969 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.2191 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.4616 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.6482 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.4823 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.5410 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.5297 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.5265 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.8432 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 3.0136 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9302 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9089 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.1484 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.0304 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 3.0000 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.1218 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9779 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.1819 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9684 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 3.1650 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9694 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.8543 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.1193 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9270 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 2.9716 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8867 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9948 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9963 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9818 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 3.0803 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.1781 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0422 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.2487 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9344 seconds
# Retrain using C* = 50...
# **Training: Epoch 1 finished in 4.1440 seconds
# Testing...
# Prediction mistake count...
# Run: 15
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.2464 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.2124 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.2578 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.2738 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.5651 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.7572 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.6341 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.4669 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.4438 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.4751 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 3.0041 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0280 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.8753 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8760 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.0552 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 2.9653 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9408 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9423 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.1279 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.0255 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 3.0351 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0159 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9348 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8841 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9573 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 2.9570 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9326 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.8493 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9609 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.0368 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 2.9748 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9542 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0114 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.1647 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.1208 seconds
# Retrain using C* = 10...
# **Training: Epoch 1 finished in 4.2214 seconds
# Testing...
# Prediction mistake count...
# Run: 16
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.3362 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.3092 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.4351 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.3763 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.2470 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.4268 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.6956 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.6271 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.4935 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.5378 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 2.9021 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8900 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0052 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0129 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9257 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 3.0034 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9506 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9883 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9076 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9566 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 3.0788 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0157 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0464 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9436 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9314 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 2.9295 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8908 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.1973 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.1592 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.0386 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 3.0423 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0219 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9600 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8964 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9637 seconds
# Retrain using C* = 10...
# **Training: Epoch 1 finished in 4.4712 seconds
# Testing...
# Prediction mistake count...
# Run: 17
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.3634 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.2322 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.2238 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.3452 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.2818 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.5288 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.4503 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.4819 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.5552 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.5372 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 3.0028 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8819 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9532 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9259 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9227 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 2.9189 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8686 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9128 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9695 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8992 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 2.9305 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8740 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9354 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9884 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9173 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 2.9509 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8696 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9219 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9502 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8997 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 2.9274 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8713 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9200 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9671 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9129 seconds
# Retrain using C* = 10...
# **Training: Epoch 1 finished in 4.0170 seconds
# Testing...
# Prediction mistake count...
# Run: 18
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.4295 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.2518 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.2093 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.2376 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.2508 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.6345 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.3932 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.7330 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.4894 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.5244 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 3.1675 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.1728 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.0596 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0084 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.0605 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 3.0388 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8633 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9013 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9088 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.0014 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 3.0805 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.0009 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9831 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0113 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.0784 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 3.2093 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.1422 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9422 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.1415 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.0963 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 2.9750 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8957 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.8577 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9263 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9578 seconds
# Retrain using C* = 10...
# **Training: Epoch 1 finished in 4.1733 seconds
# Testing...
# Prediction mistake count...
# Run: 19
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.2182 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.2496 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.1939 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.2135 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.2175 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.4012 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.4455 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.3964 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.4447 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.4379 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 2.8668 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9142 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.8852 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8582 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9119 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 2.8513 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9251 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.8748 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8401 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8930 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 2.8587 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9158 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.8881 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8239 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9098 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 2.8421 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9220 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.8670 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8547 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9067 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 2.8566 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.9164 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.8682 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8270 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.9089 seconds
# Retrain using C* = 10...
# **Training: Epoch 1 finished in 3.9999 seconds
# Testing...
# Prediction mistake count...
# Run: 20
# d = 0.5
# fold: 1
# **Training: Epoch 1 finished in 4.2198 seconds
# fold: 2
# **Training: Epoch 1 finished in 4.1432 seconds
# fold: 3
# **Training: Epoch 1 finished in 4.2592 seconds
# fold: 4
# **Training: Epoch 1 finished in 4.2774 seconds
# fold: 5
# **Training: Epoch 1 finished in 4.1483 seconds
# d = 1
# fold: 1
# **Training: Epoch 1 finished in 3.4646 seconds
# fold: 2
# **Training: Epoch 1 finished in 3.3540 seconds
# fold: 3
# **Training: Epoch 1 finished in 3.4454 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.4725 seconds
# fold: 5
# **Training: Epoch 1 finished in 3.4115 seconds
# d = 10
# fold: 1
# **Training: Epoch 1 finished in 2.8806 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8311 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.8902 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.8909 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8001 seconds
# d = 50
# fold: 1
# **Training: Epoch 1 finished in 2.8750 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8934 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9748 seconds
# fold: 4
# **Training: Epoch 1 finished in 3.0568 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8354 seconds
# d = 100
# fold: 1
# **Training: Epoch 1 finished in 2.9163 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8275 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9280 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9422 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8706 seconds
# d = 500
# fold: 1
# **Training: Epoch 1 finished in 2.9419 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8224 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.9179 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9116 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8595 seconds
# d = 1000
# fold: 1
# **Training: Epoch 1 finished in 2.8897 seconds
# fold: 2
# **Training: Epoch 1 finished in 2.8422 seconds
# fold: 3
# **Training: Epoch 1 finished in 2.8970 seconds
# fold: 4
# **Training: Epoch 1 finished in 2.9439 seconds
# fold: 5
# **Training: Epoch 1 finished in 2.8290 seconds
# Retrain using C* = 10...
# **Training: Epoch 1 finished in 3.9999 seconds
# Testing...
# Prediction mistake count...
# Results 1b):
# Testing error per run: [0.023118279569892472, 0.023118279569892472, 0.01935483870967742, 0.017741935483870968, 0.025806451612903226, 0.024193548387096774, 0.026344086021505377, 0.01881720430107527, 0.025268817204301075, 0.02956989247311828, 0.023118279569892472, 0.02795698924731183, 0.01827956989247312, 0.01935483870967742, 0.02258064516129032, 0.01935483870967742, 0.023655913978494623, 0.023118279569892472, 0.021505376344086023, 0.02204301075268817]
# d* per run: [10, 10, 10, 10, 10, 10, 10, 10, 10, 50, 10, 10, 10, 50, 10, 10, 10, 10, 10, 10]
# Mean and STD of testing error: 0.02271505376344086 +- 0.003184661433687941
# Mean and STD of d*: 14.0 +- 12.0
#
# Results 1c):
# Mean confusion matrix:
# [[0.         0.         0.00177086 0.00176714 0.00128392 0.00227989
#   0.00095956 0.         0.00015823 0.00016181]
#  [0.         0.         0.         0.0001938  0.00176016 0.00021008
#   0.00257879 0.00021834 0.00116883 0.        ]
#  [0.00081848 0.00052923 0.         0.0033184  0.00442403 0.00473742
#   0.         0.00240557 0.00216352 0.        ]
#  [0.00212297 0.00088673 0.0083575  0.         0.00126714 0.0115227
#   0.         0.00180477 0.01096609 0.00089186]
#  [0.00197285 0.0032533  0.00774398 0.         0.         0.00056349
#   0.00294392 0.00153222 0.00207229 0.00671572]
#  [0.00833128 0.00033113 0.00402635 0.01071507 0.00529044 0.
#   0.00627781 0.0003125  0.00422959 0.00379836]
#  [0.00440043 0.00205642 0.0030113  0.         0.00434055 0.00351011
#   0.         0.         0.00175711 0.        ]
#  [0.0002907  0.00121923 0.00556938 0.00063092 0.0039773  0.
#   0.         0.         0.00481067 0.01020443]
#  [0.00694686 0.00272923 0.00485443 0.00744693 0.00826859 0.00959107
#   0.00101039 0.0041324  0.         0.0017513 ]
#  [0.00066237 0.         0.0003268  0.00154628 0.00929012 0.
#   0.         0.00921992 0.00030864 0.        ]]
# STD confusion matrix:
# [[0.         0.         0.00276079 0.0021415  0.00212236 0.0021163
#   0.00146638 0.         0.0006897  0.00070532]
#  [0.         0.         0.         0.00084475 0.00194906 0.00091574
#   0.00227703 0.00095172 0.00178705 0.        ]
#  [0.00195303 0.00158792 0.         0.00456563 0.00513825 0.0042022
#   0.         0.00266155 0.00312768 0.        ]
#  [0.00289901 0.00211465 0.00546359 0.         0.00253594 0.01034468
#   0.         0.0027676  0.00795412 0.00212412]
#  [0.00322961 0.00394128 0.00736634 0.         0.         0.00169066
#   0.00295949 0.00266479 0.00283701 0.00572949]
#  [0.00674339 0.00144334 0.00449019 0.00920252 0.00633685 0.
#   0.00638706 0.00136216 0.00579396 0.00484375]
#  [0.00435348 0.00330431 0.00406996 0.         0.00396343 0.00353962
#   0.         0.         0.00269052 0.        ]
#  [0.00126712 0.0030167  0.00443973 0.00189277 0.00541519 0.
#   0.         0.         0.00463223 0.00569638]
#  [0.00657618 0.00397014 0.00576452 0.0054124  0.00742442 0.00683892
#   0.00241037 0.00528565 0.         0.00303703]
#  [0.0019873  0.         0.00142448 0.00337762 0.00748675 0.
#   0.         0.00597813 0.00134534 0.        ]]
#
# Results 1d):

# %%
train
# Out:
# SVC(C=10, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
